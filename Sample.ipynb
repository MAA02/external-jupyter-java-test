// %% [markdown]
// # Java Basics 101

// %% [markdown]
// Hi all! This is a Jupyter notebook for getting started with Java! You should be able to write and run blocks of Java code :)).

// %% [markdown]
// ### Variables and data types

// %%
System.out.println("Hello World");
// Out:
// Hello World

// %%
int hellos = 1;
hellos += 1;
System.out.println(hellos);
// Out:
// 2

// %%
System.out.println(hellos);
// Out:
// 2

// %% [markdown]
// ### Objects and Classes

// %% [markdown]
// ### Interfaces and Subclasses

// %% [markdown]
// ### Errors and exceptions
